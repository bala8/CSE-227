# %%
import urllib2
import os
from bs4 import BeautifulSoup
import re
from datetime import datetime
import csv

# %%
os.chdir('./Downloads')

# %%
d = {}
foundation = 1

# %%
def foundationalTotal(filename,year):
    with open(filename) as csvDataFile:
            csvReader = csv.reader(csvDataFile)
            next(csvReader, None)
            d[year] = (0,0)
            for row in csvReader:
                row[1] = row[1].strip()
                if row[1] == '' or row[1] == '-':
                    continue
                verSplit = row[1].split('.')
                #print row[1]
                try:
                    if(int(verSplit[0]) <= foundation):
                        d[year] += 1
                except ValueError:
                    continue

# %%
v = []
def versions(filename,year):
    with open(filename) as csvDataFile:
            csvReader = csv.reader(csvDataFile)
            next(csvReader, None)
            #d[year] = 
            for row in csvReader:
                row[1] = row[1].strip()
                if row[1] == '' or row[1] == '-':
                    continue
                v.append(row[1])

# %%
foundationalTotal("firefox2016.csv",2016)

# %%
foundationalTotal("firefox2015.csv",2015)

# %%
foundationalTotal("firefox2014.csv",2014)

# %%
foundationalTotal("firefox2013.csv",2013)

# %%
foundationalTotal("firefox2012.csv",2012)

# %%
foundationalTotal("firefox2011.csv",2011)

# %%
foundationalTotal("firefox2010.csv",2010)

# %%
foundationalTotal("firefox2009.csv",2009)

# %%
foundationalTotal("firefox2008.csv",2008)

# %%
foundationalTotal("firefox2007.csv",2007)

# %%
foundationalTotal("firefox2006.csv",2006)

# %%
print d
# Out:
# {2016: 0, 2006: 44, 2007: 32, 2008: 26, 2009: 62, 2010: 47, 2011: 44, 2012: 101, 2013: 55, 2014: 47, 2015: 18}

# %%
versions("firefox2006.csv",2006)
versions("firefox2007.csv",2007)
versions("firefox2008.csv",2008)
versions("firefox2009.csv",2009)
versions("firefox2010.csv",2010)
versions("firefox2011.csv",2011)
versions("firefox2012.csv",2012)
versions("firefox2013.csv",2013)
versions("firefox2014.csv",2014)
versions("firefox2015.csv",2015)
versions("firefox2016.csv",2016)

# %%
dates = ['2011-09-27','2012-04-24','2011-08-16','2015-03-31','2014-03-24','2012-01-31','2015-12-15','2009-04-27','2012-10-09','2010-03-30','2015-12-18', 
        '2016-01-06','2009-08-03','2009-07-16','2015-07-02','2015-08-13','2015-08-27','2016-04-11','2016-03-16','2009-02-03',
        '2009-03-04','2008-11-12','2007-05-30','2008-09-23','2008-09-26','2008-07-16','2009-04-21','2010-01-21','2009-06-30',
        '2012-02-17','2008-06-17','2008-07-28','2006-10-24','2014-12-1','2008-02-07','2007-11-30','2008-04-16','2007-11-01',
        '2007-10-18','2007-09-18', '2007-07-30', '2007-07-17', '2007-04-30', '2007-03-20', '2006-12-19', '2016-08-24', 
         '2014-02-04', '2014-05-09', '2015-04-03','2015-04-20', '2007-02-23', '2010-01-21', '2010-03-22', '2010-04-01',
         '2010-07-20', '2014-09-02', '2014-10-14', '2004-02-09', '2015-11-03', '2008-12-16', '2013-02-19', '2015-07-02',
         '2011-11-08', '2006-10-24', '2014-06-10', '2010-06-22', '2015-09-22', '2006-06-01', '2006-09-14', '2006-08-02',
         '2006-02-01', '2014-03-18', '2015-10-15', '2015-09-30', '2006-12-19', '2006-11-07', '2016-06-28', '2005-11-29', 
         '2004-11-09', '2006-10-24', '2002-09-23', '2002-10-01', '2007-04-30', '2015-04-12', '2015-08-06', '2015-03-05', 
         '2015-03-20', '2016-02-11', '2015-03-21', '2016-02-08', '2011-03-22', '2008-04-02', '2016-04-03']

# %%
temp = set(v)
temp.remove("[[datetime.datetime(2011, 1, 6, 17, 44), datetime.datetime(2011, 1, 6, 17, 46), u'Canvas: WebGL', []]]")
v = list(temp)
print v
# Out:
# ['7.0', '12.0', '6.0', '37.0', '28.0.1', '10.0', '43.0', '3.0.10', '16.0', '3.0.19', '43.0.1', '43.0.4', '3.5.2', '3.5.1', '38.1.0', '40.0.2', '40.0.3', '45.0.2', '45.0.1', '3.0.6', '3.0.7', '3.0.4', '1.5.0.12', '3.0.2', '3.0.3', '3.0.1', '3.0.9', '3.6', '3.5', '3.6.27', '3.0', '3.1', '2.0', '34.0.5', '2.0.0.12', '2.0.0.11', '2.0.0.14', '2.0.0.9', '2.0.0.8', '2.0.0.7', '2.0.0.6', '2.0.0.5', '2.0.0.4', '2.0.0.3', '2.0.0.1', '48.0.2', '27.0', '29.0.1', '37.0.1', '37.0.2', '1.5.0.10', '3.6.1', '3.6.2', '3.6.3', '3.6.7', '32.0', '33.0', '0.8', '42.0', '3.0.5', '19.0', '39.0', '8.0', '2', '30.0', '3.5.10', '41.0', '1.5.0.4', '1.5.0.7', '1.5.0.6', '1.5.0.1', '28.0', '41.0.2', '41.0.1', '1.5.0.9', '1.5.0.8', '47.0.1', '1.5', '1.0', '2.0 8', '0.1', '0.2', '1.8', '38.0', '39.0.3', '36.0.1', '36.0.3', '44.0.2', '36.0.4', '44.0.1', '4.0', '3.0beta5', '46.0.1']

# %%
versionDict = {}
for key,value in zip(v,dates):
    value = datetime.strptime(value, '%Y-%m-%d')
    versionDict[key] = value

# %%
print versionDict
# Out:
# {'7.0': datetime.datetime(2011, 9, 27, 0, 0), '12.0': datetime.datetime(2012, 4, 24, 0, 0), '6.0': datetime.datetime(2011, 8, 16, 0, 0), '37.0': datetime.datetime(2015, 3, 31, 0, 0), '28.0.1': datetime.datetime(2014, 3, 24, 0, 0), '10.0': datetime.datetime(2012, 1, 31, 0, 0), '1.5.0.8': datetime.datetime(2006, 11, 7, 0, 0), '3.0.10': datetime.datetime(2009, 4, 27, 0, 0), '16.0': datetime.datetime(2012, 10, 9, 0, 0), '3.0.19': datetime.datetime(2010, 3, 30, 0, 0), '43.0.1': datetime.datetime(2015, 12, 18, 0, 0), '43.0.4': datetime.datetime(2016, 1, 6, 0, 0), '3.5.2': datetime.datetime(2009, 8, 3, 0, 0), '3.5.1': datetime.datetime(2009, 7, 16, 0, 0), '38.1.0': datetime.datetime(2015, 7, 2, 0, 0), '40.0.2': datetime.datetime(2015, 8, 13, 0, 0), '40.0.3': datetime.datetime(2015, 8, 27, 0, 0), '45.0.2': datetime.datetime(2016, 4, 11, 0, 0), '45.0.1': datetime.datetime(2016, 3, 16, 0, 0), '3.0.6': datetime.datetime(2009, 2, 3, 0, 0), '3.0.7': datetime.datetime(2009, 3, 4, 0, 0), '3.0.4': datetime.datetime(2008, 11, 12, 0, 0), '1.5.0.12': datetime.datetime(2007, 5, 30, 0, 0), '3.0.2': datetime.datetime(2008, 9, 23, 0, 0), '3.0.3': datetime.datetime(2008, 9, 26, 0, 0), '3.0.1': datetime.datetime(2008, 7, 16, 0, 0), '3.0.9': datetime.datetime(2009, 4, 21, 0, 0), '3.6': datetime.datetime(2010, 1, 21, 0, 0), '3.5': datetime.datetime(2009, 6, 30, 0, 0), '3.6.27': datetime.datetime(2012, 2, 17, 0, 0), '3.0': datetime.datetime(2008, 6, 17, 0, 0), '3.1': datetime.datetime(2008, 7, 28, 0, 0), '2.0': datetime.datetime(2006, 10, 24, 0, 0), '34.0.5': datetime.datetime(2014, 12, 1, 0, 0), '2.0.0.12': datetime.datetime(2008, 2, 7, 0, 0), '2.0.0.11': datetime.datetime(2007, 11, 30, 0, 0), '2.0.0.14': datetime.datetime(2008, 4, 16, 0, 0), '2.0.0.9': datetime.datetime(2007, 11, 1, 0, 0), '2.0.0.8': datetime.datetime(2007, 10, 18, 0, 0), '2.0.0.7': datetime.datetime(2007, 9, 18, 0, 0), '2.0.0.6': datetime.datetime(2007, 7, 30, 0, 0), '2.0.0.5': datetime.datetime(2007, 7, 17, 0, 0), '2.0.0.4': datetime.datetime(2007, 4, 30, 0, 0), '2.0.0.3': datetime.datetime(2007, 3, 20, 0, 0), '2.0.0.1': datetime.datetime(2006, 12, 19, 0, 0), '48.0.2': datetime.datetime(2016, 8, 24, 0, 0), '27.0': datetime.datetime(2014, 2, 4, 0, 0), '29.0.1': datetime.datetime(2014, 5, 9, 0, 0), '37.0.1': datetime.datetime(2015, 4, 3, 0, 0), '37.0.2': datetime.datetime(2015, 4, 20, 0, 0), '3.6.1': datetime.datetime(2010, 1, 21, 0, 0), '3.6.2': datetime.datetime(2010, 3, 22, 0, 0), '3.6.3': datetime.datetime(2010, 4, 1, 0, 0), '3.6.7': datetime.datetime(2010, 7, 20, 0, 0), '32.0': datetime.datetime(2014, 9, 2, 0, 0), '1.5': datetime.datetime(2005, 11, 29, 0, 0), '33.0': datetime.datetime(2014, 10, 14, 0, 0), '1.5.0.10': datetime.datetime(2007, 2, 23, 0, 0), '42.0': datetime.datetime(2015, 11, 3, 0, 0), '3.0.5': datetime.datetime(2008, 12, 16, 0, 0), '1.0': datetime.datetime(2004, 11, 9, 0, 0), '39.0': datetime.datetime(2015, 7, 2, 0, 0), '8.0': datetime.datetime(2011, 11, 8, 0, 0), '2': datetime.datetime(2006, 10, 24, 0, 0), '30.0': datetime.datetime(2014, 6, 10, 0, 0), '3.5.10': datetime.datetime(2010, 6, 22, 0, 0), '41.0': datetime.datetime(2015, 9, 22, 0, 0), '1.5.0.4': datetime.datetime(2006, 6, 1, 0, 0), '1.5.0.7': datetime.datetime(2006, 9, 14, 0, 0), '1.5.0.6': datetime.datetime(2006, 8, 2, 0, 0), '1.5.0.1': datetime.datetime(2006, 2, 1, 0, 0), '28.0': datetime.datetime(2014, 3, 18, 0, 0), '41.0.2': datetime.datetime(2015, 10, 15, 0, 0), '41.0.1': datetime.datetime(2015, 9, 30, 0, 0), '1.5.0.9': datetime.datetime(2006, 12, 19, 0, 0), '43.0': datetime.datetime(2015, 12, 15, 0, 0), '47.0.1': datetime.datetime(2016, 6, 28, 0, 0), '0.8': datetime.datetime(2004, 2, 9, 0, 0), '19.0': datetime.datetime(2013, 2, 19, 0, 0), '2.0 8': datetime.datetime(2006, 10, 24, 0, 0), '0.1': datetime.datetime(2002, 9, 23, 0, 0), '0.2': datetime.datetime(2002, 10, 1, 0, 0), '1.8': datetime.datetime(2007, 4, 30, 0, 0), '38.0': datetime.datetime(2015, 4, 12, 0, 0), '39.0.3': datetime.datetime(2015, 8,  ...

# %%
len(temp)
# Out:
# 93

# %%
cveDict = {}
def cveCreator(filename,year):
    with open(filename) as csvDataFile:
            csvReader = csv.reader(csvDataFile)
            next(csvReader, None)
            #d[year] = (0,0)
            for row in csvReader:
                row[1] = row[1].strip()
                row[0] = row[0].strip()
                #print row[0]
                cveDict[row[0]] = row[1]

# %%
cveCreator("firefox2006.csv",2006)
cveCreator("firefox2007.csv",2007)
cveCreator("firefox2008.csv",2008)
cveCreator("firefox2009.csv",2009)
cveCreator("firefox2010.csv",2010)
cveCreator("firefox2011.csv",2011)
cveCreator("firefox2012.csv",2012)
cveCreator("firefox2013.csv",2013)
cveCreator("firefox2014.csv",2014)
cveCreator("firefox2015.csv",2015)
cveCreator("firefox2016.csv",2016)

# %%
print cveDict
# Out:
# {'CVE-2014-1588': '33.0', 'CVE-2012-4218': '0.1', 'CVE-2007-3074': '2.0', 'CVE-2012-4212': '0.1', 'CVE-2015-7218': '42.0', 'CVE-2012-4210': '0.1', 'CVE-2012-4217': '0.1', 'CVE-2012-4216': '0.1', 'CVE-2007-3072': '2.0', 'CVE-2007-3073': '2.0.0.4', 'CVE-2016-5279': '48.0.2', 'CVE-2014-1568': '32.0', 'CVE-2009-2468': '0.1', 'CVE-2009-2469': '', 'CVE-2007-2176': '', 'CVE-2014-1539': '29.0.1', 'CVE-2009-2462': '0.1', 'CVE-2009-2463': '0.1', 'CVE-2013-5592': '19.0', 'CVE-2008-5715': '3.0.5', 'CVE-2009-2466': '0.1', 'CVE-2009-2467': '0.1', 'CVE-2009-2464': '0.1', 'CVE-2009-2465': '0.1', 'CVE-2016-1949': '44.0.1', 'CVE-2014-8641': '34.0.5', 'CVE-2007-4841': '2.0.0.8', 'CVE-2008-4059': '', 'CVE-2012-5354': '1.0', 'CVE-2008-3835': '0.8', 'CVE-2012-4213': '0.1', 'CVE-2008-3837': '0.8', 'CVE-2008-3836': '0.8', 'CVE-2008-3444': '3.0', 'CVE-2012-3982': '1.0', 'CVE-2015-7216': '42.0', 'CVE-2009-0733': '3.1', 'CVE-2014-1577': '30.0', 'CVE-2012-4215': '0.1', 'CVE-2015-4496': '37.0.2', 'CVE-2016-5252': '47.0.1', 'CVE-2007-0896': '', 'CVE-2012-4214': '0.1', 'CVE-2007-2671': '2.0.0.3', 'CVE-2015-2710': '37.0.2', 'CVE-2015-2713': '37.0.2', 'CVE-2015-2712': '37.0.2', 'CVE-2015-2715': '37.0.2', 'CVE-2015-2714': '37.0.2', 'CVE-2015-2717': '37.0.2', 'CVE-2015-7223': '42.0', 'CVE-2007-3089': '0.8', 'CVE-2015-2718': '37.0.2', 'CVE-2015-7189': '41.0.2', 'CVE-2007-0008': '0.1', 'CVE-2007-0009': '1.5.0.9', 'CVE-2015-7188': '41.0.2', 'CVE-2012-0442': '0.1', 'CVE-2012-3980': '1.0', 'CVE-2016-5259': '47.0.1', 'CVE-2007-1970': '', 'CVE-2015-7200': '41.0.2', 'CVE-2015-7201': '42.0', 'CVE-2011-0085': '1.0', 'CVE-2011-0084': '1.0', 'CVE-2011-0083': '1.0', 'CVE-2011-0082': '4.0', 'CVE-2011-0081': '3.6.1', 'CVE-2011-0080': '3.5', 'CVE-2015-7183': '41.0.2', 'CVE-2012-1975': '1.0', 'CVE-2008-2810': '2.0', 'CVE-2008-2811': '2.0', 'CVE-2015-0808': '36.0.4', 'CVE-2011-2598': '4.0', 'CVE-2016-5278': '48.0.2', 'CVE-2016-2830': '47.0.1', 'CVE-2015-7213': '42.0', 'CVE-2007-3656': '1.0', 'CVE-2007-3657': '2.0.0.4', 'CVE-2015-0797': '37.0.2', 'CVE-2009-4102': '', 'CVE-2015-0819': '0.1', 'CVE-2015-0799': '37.0', 'CVE-2015-0798': '37.0', 'CVE-2015-7186': '41.0.2', 'CVE-2013-1730': '19.0', 'CVE-2013-1731': '19.0', 'CVE-2013-1732': '19.0', 'CVE-2016-1958': '44.0.2', 'CVE-2013-1735': '19.0', 'CVE-2013-1736': '19.0', 'CVE-2013-1737': '19.0', 'CVE-2013-1738': '19.0', 'CVE-2014-8637': '34.0.5', 'CVE-2007-1377': '2.0.0.3', 'CVE-2008-0412': '2.0.0.11', 'CVE-2008-0413': '2.0.0.11', 'CVE-2012-3984': '1.0', 'CVE-2012-3985': '1.0', 'CVE-2008-0416': '2.0.0.11', 'CVE-2008-0417': '2.0.0.11', 'CVE-2008-0414': '2.0.0.11', 'CVE-2008-0415': '2.0.0.11', 'CVE-2008-5507': '2.0', 'CVE-2008-5506': '2.0', 'CVE-2008-5505': '3.0', 'CVE-2008-0419': '2.0.0.11', 'CVE-2008-5503': '2.0', 'CVE-2008-5502': '2.0', 'CVE-2008-5501': '2.0', 'CVE-2008-5500': '2.0', 'CVE-2015-4511': '40.0.3', 'CVE-2015-4510': '40.0.3', 'CVE-2015-4513': '41.0.2', 'CVE-2015-4512': '40.0.3', 'CVE-2015-4515': '41.0.2', 'CVE-2015-4514': '41.0.2', 'CVE-2015-4517': '40.0.3', 'CVE-2015-4516': '40.0.3', 'CVE-2015-4519': '40.0.3', 'CVE-2015-4518': '41.0.2', 'CVE-2016-1944': '43.0.4', 'CVE-2013-0774': '0.1', 'CVE-2016-5282': '48.0.2', 'CVE-2014-1520': '0.1', 'CVE-2014-1522': '0.1', 'CVE-2014-1523': '0.1', 'CVE-2014-1524': '0.1', 'CVE-2008-0591': '2.0.0.11', 'CVE-2014-1526': '0.1', 'CVE-2014-1527': '0.1', 'CVE-2014-1528': '28.0', 'CVE-2014-1529': '0.1', 'CVE-2007-0776': '2.0.0.1', 'CVE-2007-5691': '2.0.0.7', 'CVE-2016-2814': '45.0.1', 'CVE-2008-5021': '0.8', 'CVE-2008-5022': '0.8', 'CVE-2008-5023': '0.8', 'CVE-2008-5024': '0.8', 'CVE-2013-0764': '0.1', 'CVE-2013-0765': '0.1', 'CVE-2010-1988': '3.6.3', 'CVE-2013-0767': '0.1', 'CVE-2013-0760': '0.1', 'CVE-2007-4879': '0.1', 'CVE-2013-0762': '0.1', 'CVE-2013-0763': '0.1', 'CVE-2007-0777': '1.5.0.9', 'CVE-2014-1478': '0.1', 'CVE-2010-1986': '3.6.3', 'CVE-2010-1987': '3.6.3', 'CVE-2012-0468': '4.0', 'CVE-2012-0469': '4.0', 'CVE-2012-0460': '4.0', 'CVE-2012-0461': '3.6.27', 'CVE-2012-0462': '4.0', 'CV ...

# %%
first = 0
second = 0
for key,val in d.iteritems():
    if key < 2011:
        first = first + val
    else:
        second = second + val

# %%
print first, second
# Out:
# 211 265

# %%
d2 = {}

# %%
p = 0
def versionWiseTotal(filename):
    with open(filename) as csvDataFile:
            csvReader = csv.reader(csvDataFile)
            next(csvReader, None)
            for row in csvReader:
                try:
                    row[1] = row[1].strip()
                    row[2] = row[2].strip()
                    if row[1] == '' or row[1] == '-' or row[2] == '' or row[2] == '-':
                        continue
                    startVerSplit = int(row[1].split('.')[0])
                    endVerSplit = int(row[2].split('.')[0])+1
                    #print row[1]
                    if startVerSplit < foundation:
                        startVerSplit = foundation
                    if endVerSplit < foundation:
                        endVerSplit = foundation
                    if (startVerSplit,endVerSplit) in d2:
                        d2[(startVerSplit,endVerSplit)] += 1
                    else:
                        d2[(startVerSplit,endVerSplit)] = 1
                    p+=1
                except Exception:
                    continue

# %%
files = ['firefox2016.csv','firefox2015.csv', 'firefox2014.csv', 'firefox2013.csv', 'firefox2012.csv', 'firefox2011.csv', 'firefox2010.csv', 'firefox2009.csv', 'firefox2008.csv', 'firefox2007.csv', 'firefox2006.csv']

# %%
for file in files:
    versionWiseTotal(file)

# %%
d2
# Out:
# {(5, 5): 488,
#  (5, 6): 11,
#  (5, 7): 11,
#  (5, 8): 7,
#  (5, 9): 5,
#  (5, 10): 17,
#  (5, 11): 4,
#  (5, 12): 12,
#  (5, 13): 10,
#  (5, 14): 19,
#  (5, 15): 32,
#  (5, 16): 25,
#  (5, 17): 35,
#  (5, 18): 27,
#  (5, 19): 14,
#  (5, 20): 1,
#  (5, 26): 13,
#  (5, 27): 15,
#  (5, 28): 19,
#  (5, 29): 13,
#  (5, 36): 18,
#  (6, 7): 1,
#  (7, 8): 2,
#  (8, 9): 2,
#  (10, 11): 1,
#  (12, 13): 2,
#  (16, 17): 1,
#  (19, 20): 13,
#  (19, 21): 14,
#  (19, 22): 17,
#  (19, 23): 15,
#  (19, 24): 19,
#  (19, 25): 14,
#  (19, 26): 1,
#  (27, 28): 1,
#  (28, 29): 3,
#  (29, 30): 10,
#  (30, 31): 14,
#  (30, 32): 8,
#  (30, 33): 12,
#  (32, 33): 1,
#  (33, 34): 11,
#  (34, 35): 10,
#  (36, 37): 18,
#  (37, 38): 18,
#  (38, 39): 19,
#  (39, 40): 20,
#  (40, 41): 30,
#  (41, 42): 24,
#  (41, 43): 1,
#  (42, 43): 21,
#  (43, 44): 18,
#  (44, 45): 42,
#  (45, 46): 13,
#  (46, 47): 14,
#  (47, 48): 24,
#  (48, 49): 18}

# %%
p
# Out:
# 0

# %%
p
# Out:
# 0

# %%
d3 = {}
def durationB(filename):
    #print "woof"
    with open(filename) as csvDataFile:
            csvReader = csv.reader(csvDataFile)
            next(csvReader, None)
            #d[year] = 0
            for row in csvReader:
                #try:
                bugs = row[3].replace('[','').split('],')
                #lists = [map(int, s.replace(']','').split(',')) for s in bugs]
                print bugs
                    #print type(bugs)
                    
                #except Exception, e:
                    #print Exception
                    #continue

# %%
files = ['firefox2016.csv','firefox2015.csv', 'firefox2014.csv', 'firefox2013.csv', 'firefox2012.csv', 'firefox2011.csv', 'firefox2010.csv', 'firefox2009.csv', 'firefox2008.csv', 'firefox2007.csv', 'firefox2006.csv']

# %%
for file in files:
   durationB(file)
# Out:
# [']']
# [']']
# ["datetime.datetime(2016, 9, 15, 12, 14), datetime.datetime(2016, 9, 21, 15, 54), u'Security: PSM', u'(firefox48 wontfix', u' firefox49 fixed', u' firefox50 fixed', u' firefox51 fixed)']]]"]
# ["datetime.datetime(2013, 10, 17, 17, 4), datetime.datetime(2017, 2, 9, 7, 55), u'Layout', u'(firefox47+ wontfix', u' firefox48 wontfix', u' firefox49 fixed', u' firefox50 fixed)']]]"]
# ["datetime.datetime(2013, 10, 29, 8, 44), datetime.datetime(2016, 5, 23, 21, 56), u'Favicon Handling', u'(firefox25 ?', u' firefox26 ?', u' firefox27 affected', u' firefox49 fixed)']]]"]
# ["datetime.datetime(2016, 7, 5, 16, 16), datetime.datetime(2016, 7, 26, 10, 4), u'DOM', u'(firefox47 wontfix', u' firefox48- wontfix', u' firefox49+ fixed', u' firefox50+ fixed)']]]"]
# ["datetime.datetime(2016, 7, 27, 19, 54), datetime.datetime(2016, 8, 12, 16, 18), u'DOM: Core & HTML', u'(firefox48 wontfix', u' firefox49+ verified', u' firefox50+ verified', u' firefox51+ verified)']]]"]
# ["datetime.datetime(2016, 2, 18, 20, 14), datetime.datetime(2016, 4, 29, 12, 31), u'Drag and Drop', u'(firefox49 verified)']]]"]
# ["datetime.datetime(2016, 8, 12, 5, 55), datetime.datetime(2016, 8, 18, 14, 17), u'Canvas: 2D', u'(firefox48 wontfix', u' firefox49+ verified', u' firefox50+ verified', u' firefox51+ verified)']]]"]
# ["datetime.datetime(2016, 8, 3, 4, 48), datetime.datetime(2016, 8, 16, 19, 54), u'DOM: Animation', u'(firefox48 wontfix', u' firefox49+ verified', u' firefox50+ verified', u' firefox51+ verified)']]]"]
# ["datetime.datetime(2016, 7, 19, 2, 2), datetime.datetime(2016, 8, 23, 11, 40), u'Disability Access APIs', u'(firefox48 wontfix', u' firefox49+ verified', u' firefox50+ verified', u' firefox51+ fixed)']]]"]
# ["datetime.datetime(2016, 7, 17, 1, 32), datetime.datetime(2016, 8, 26, 8, 52), u'Canvas: 2D', u'(firefox47 wontfix', u' firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51 fixed)']]]"]
# ["datetime.datetime(2016, 6, 24, 7, 10), datetime.datetime(2016, 9, 21, 23, 46), u'DOM: Animation', u'(firefox47+ wontfix', u' firefox48+ wontfix', u' firefox49+ verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 6, 16, 2, 42), datetime.datetime(2017, 3, 29, 0, 49), u'Disability Access APIs', u'(firefox47 wontfix', u' firefox48 affected', u' firefox49 verified', u' firefox50 verified)']]]"]
# ["datetime.datetime(2016, 8, 24, 21, 36), datetime.datetime(2016, 8, 25, 15, 37), u'Layout', u'(firefox48 wontfix', u' firefox49+ verified', u' firefox50+ verified', u' firefox51+ verified)']]]"]
# ["datetime.datetime(2016, 7, 23, 22, 40), datetime.datetime(2016, 8, 16, 12, 3), u'Layout: Text', u'(firefox48 wontfix', u' firefox49 verified', u' firefox50 verified', u' firefox51 verified)']]]"]
# ["datetime.datetime(2016, 8, 1, 14, 2), datetime.datetime(2016, 8, 23, 19, 46), u'Layout: Text', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ verified', u' firefox51+ verified)']]]"]
# ["datetime.datetime(2016, 3, 4, 10, 27), datetime.datetime(2016, 4, 14, 9, 4), u'Networking', u'(firefox48 fixed)']]]"]
# ["datetime.datetime(2016, 7, 4, 19, 42), datetime.datetime(2016, 7, 6, 5, 11), u'General', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2015, 11, 22, 11, 3), datetime.datetime(2016, 4, 19, 12, 20), u'Drag and Drop', u'(firefox48 fixed)']]]"]
# ["datetime.datetime(2016, 6, 3, 18, 6), datetime.datetime(2016, 6, 22, 8, 20), u'Networking: File', u'(firefox46 wontfix', u' firefox47 wontfix', u' firefox48 fixed', u' firefox49 fixed', u' firefox50 fixed)']]]"]
# ["datetime.datetime(2016, 7, 12, 1, 33), datetime.datetime(2016, 7, 14, 16, 48), u'DOM', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 5, 31, 5, 5), datetime.datetime(2016, 5, 31, 18, 32), u'Layout', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 6, 2, 0, 56), datetime.datetime(2016, 6, 8, 5, 16), u'DOM: Security', u'(firefox48 verified', u' firefox49 verified', u' firefox50 verified)']]]"]
# ["datetime.datetime(2016, 7, 16, 3, 33), datetime.datetime(2016, 7, 20, 5, 5), u'Networking: WebSockets', u'(firefox47 wontfix', u' firefox48 fixed', u' firefox49 fixed', u' firefox50 fixed)']]]"]
# ["datetime.datetime(2016, 6, 15, 10, 2), datetime.datetime(2016, 6, 29, 13, 42), u'Session Restore', u'(firefox48+ fixed', u' firefox49+ fixed', u' firefox50 fixed)']]]"]
# ["datetime.datetime(2016, 6, 28, 18, 24), datetime.datetime(2016, 6, 30, 20, 23), u'DOM: Workers', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 6, 8, 22, 58), datetime.datetime(2016, 7, 11, 11, 47), u'WebRTC', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ fixed', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 8, 11, 5, 21), datetime.datetime(2016, 8, 11, 17, 44), u'WebRTC', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51+ fixed)']", " datetime.datetime(2016, 8, 10, 8, 38), datetime.datetime(2016, 8, 23, 7, 54), u'WebRTC: Networking', u'(firefox48 wontfix', u' firefox49+ verified', u' firefox50+ verified', u' firefox51+ verified)']", " datetime.datetime(2016, 8, 8, 10, 42), datetime.datetime(2016, 8, 11, 9, 3), u'Networking', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51+ fixed)']", " datetime.datetime(2016, 6, 1, 3, 33), datetime.datetime(2016, 8, 8, 3, 42), u'Networking: HTTP', u'(firefox47 wontfix', u' firefox48+ wontfix', u' firefox49+ verified', u' firefox50+ verified)']", " datetime.datetime(2016, 7, 15, 13, 59), datetime.datetime(2016, 7, 21, 9, 59), u'DOM', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51 fixed)']", " datetime.datetime(2016, 7, 21, 15, 23), datetime.datetime(2016, 7, 28, 13, 34), u'JavaScript Engine', u'(firefox47 wontfix', u' firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51 fixed)']", " datetime.datetime(2016, 7, 21, 19, 45), datetime.datetime(2016, 8, 13, 1, 52), u'ImageLib', u'(firefox48- wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51+ fixed)']", " datetime.datetime(2016, 7, 22, 9, 59), datetime.datetime(2016, 8, 3, 2, 26), u'JavaScript: GC', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed)']", " datetime.datetime(2016, 7, 25, 21, 49), datetime.datetime(2016, 8, 3, 18, 52), u'Audio/Video: Playback', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51+ fixed)']]]"]
# ["datetime.datetime(2016, 8, 22, 8, 15), datetime.datetime(2016, 8, 24, 0, 3), u'Audio/Video: MediaStreamGraph', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51+ fixed)']", " datetime.datetime(2016, 8, 17, 13, 52), datetime.datetime(2016, 8, 17, 13, 55), u'JavaScript Engine: JIT', u'(firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51+ fixed)']", " datetime.datetime(2016, 8, 17, 13, 27), datetime.datetime(2016, 8, 17, 13, 29), u'Audio/Video', u'(firefox48 wontfix', u' firefox49 fixed', u' firefox50 fixed', u' firefox51 fixed)']", " datetime.datetime(2016, 7, 28, 13, 27), datetime.datetime(2016, 8, 24, 13, 30), u'Graphics: Layers', u'(firefox49 fixed', u' firefox50 unaffected', u' firefox51 unaffected)']", " datetime.datetime(2016, 6, 28, 4, 37), datetime.datetime(2016, 7, 20, 14, 49), u'JavaScript Engine', u'(firefox47 wontfix', u' firefox48 wontfix', u' firefox49+ fixed', u' firefox50+ fixed', u' firefox51+ fixed)']", " datetime.datetime(2016, 5, 27, 22, 13), datetime.datetime(2016, 5, 27, 22, 55), u'ImageLib', u'(firefox47 wontfix', u' firefox48 wontfix', u' firefox49 fixed']", " datetime.datetime(2016, 4, 27, 7, 33), datetime.datetime(2016, 5, 18, 9, 25), u'JavaScript Engine', u'(firefox47 unaffected', u' firefox48 wontfix', u' firefox49 verified']]]"]
# ["datetime.datetime(2015, 10, 7, 7, 37), datetime.datetime(2016, 7, 12, 5, 36), u'JavaScript: GC', u'(firefox47 wontfix', u' firefox48- verified', u' firefox49- verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 4, 23, 7, 14), datetime.datetime(2016, 5, 2, 7, 47), u'XUL', u'(firefox48 fixed', u' firefox49 fixed)']]]"]
# ["datetime.datetime(2016, 2, 9, 6, 55), datetime.datetime(2016, 3, 23, 11, 3), u'Application Update', u'(firefox48 verified)']]]"]
# ["datetime.datetime(2016, 4, 29, 4, 9), datetime.datetime(2016, 6, 22, 8, 26), u'Graphics', u'(firefox46 wontfix', u' firefox47 wontfix', u' firefox48 fixed', u' firefox49+ fixed', u' firefox50+ fixed)']]]"]
# ["datetime.datetime(2016, 3, 10, 12, 45), datetime.datetime(2016, 3, 23, 3, 2), u'Address Bar', u'(firefox48 verified)']]]"]
# ["datetime.datetime(2016, 3, 8, 13, 17), datetime.datetime(2016, 7, 27, 18, 10), u'DOM', u'(firefox46 wontfix', u' firefox47- wontfix', u' firefox48+ fixed', u' firefox49+ fixed']]]"]
# ["datetime.datetime(2016, 5, 24, 17, 50), datetime.datetime(2016, 6, 7, 2, 14), u'Audio/Video: Playback', u'(firefox47 affected', u' firefox48 fixed', u' firefox49 fixed', u' firefox50 fixed)']]]"]
# ["datetime.datetime(2016, 6, 12, 12, 5), datetime.datetime(2016, 9, 22, 22, 33), u'Layout: Text', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 5, 20, 10, 45), datetime.datetime(2016, 5, 26, 10, 54), u'Audio/Video: Playback', u'(firefox46 wontfix', u' firefox47 wontfix', u' firefox48+ fixed', u' firefox49+ fixed', u' firefox50+ fixed)']]]"]
# ["datetime.datetime(2012, 12, 16, 0, 11), datetime.datetime(2016, 7, 5, 3, 14), u'JavaScript Engine', u'(firefox47 wontfix', u' firefox48+ fixed', u' firefox49+ fixed', u' firefox50+ fixed)']", " datetime.datetime(2016, 2, 19, 2, 23), datetime.datetime(2016, 6, 21, 19, 47), u'ImageLib', u'(firefox46+ wontfix', u' firefox47+ wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']", " datetime.datetime(2015, 4, 15, 13, 59), datetime.datetime(2016, 5, 23, 18, 4), u'DOM', u'(firefox47 wontfix', u' firefox48 fixed', u' firefox49 fixed', u' firefox50 fixed)']", " datetime.datetime(2016, 7, 1, 4, 9), datetime.datetime(2016, 7, 6, 5, 7), u'Networking', u'(firefox47 wontfix', u' firefox48+ fixed', u' firefox49+ fixed', u' firefox50+ fixed)']", " datetime.datetime(2016, 6, 27, 10, 1), datetime.datetime(2016, 7, 12, 10, 27), u'JavaScript Engine', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']", " datetime.datetime(2016, 4, 28, 12, 17), datetime.datetime(2016, 4, 29, 2, 9), u'JavaScript Engine', u'(firefox47 wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50+ verified)']", " datetime.datetime(2016, 3, 18, 21, 42), datetime.datetime(2016, 6, 7, 13, 26), u'Audio/Video: MediaStreamGraph', u'(firefox47+ wontfix', u' firefox48+ fixed', u' firefox49+ fixed', u' firefox50+ fixed)']", " datetime.datetime(2016, 3, 17, 23, 25), datetime.datetime(2016, 5, 26, 21, 58), u'Widget: Cocoa', u'(firefox47 wontfix', u' firefox48+ fixed', u' firefox49+ fixed', u' firefox50+ fixed)']]]"]
# ["datetime.datetime(2016, 6, 25, 11, 30), datetime.datetime(2016, 7, 6, 10, 15), u'Canvas: 2D', u'(firefox47 wontfix', u' firefox48+ fixed', u' firefox49+ fixed', u' firefox50+ fixed)']", " datetime.datetime(2016, 6, 15, 3, 31), datetime.datetime(2016, 6, 22, 9, 12), u'WebRTC: Networking', u'(firefox47 wontfix', u' firefox48 fixed', u' firefox49 fixed', u' firefox50 fixed)']", " datetime.datetime(2016, 5, 25, 7, 39), datetime.datetime(2016, 5, 26, 4, 46), u'Security: PSM', u'(firefox46 wontfix', u' firefox47 wontfix', u' firefox48 fixed', u' firefox49 fixed)']", " datetime.datetime(2016, 5, 5, 8, 59), datetime.datetime(2016, 5, 25, 10, 51), u'Graphics: Text', u'(firefox46 wontfix', u' firefox47 wontfix', u' firefox48+ fixed', u' firefox49+ fixed', u' firefox50+ fixed)']", " datetime.datetime(2016, 4, 15, 9, 7), datetime.datetime(2016, 4, 19, 9, 43), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47 wontfix', u' firefox48 verified']", " datetime.datetime(2016, 3, 7, 5, 15), datetime.datetime(2016, 4, 7, 1, 44), u'JavaScript Engine', u'(firefox47 wontfix', u' firefox48 fixed)']", " datetime.datetime(2015, 11, 5, 10, 19), datetime.datetime(2016, 3, 30, 18, 59), u'IPC', u'(firefox45 affected', u' firefox48 fixed']", " datetime.datetime(2016, 2, 25, 9, 54), datetime.datetime(2016, 3, 14, 6, 52), u'JavaScript Engine', u'(firefox45 unaffected', u' firefox46+ wontfix', u' firefox47+ wontfix', u' firefox48 fixed)']", " datetime.datetime(2016, 6, 16, 6, 26), datetime.datetime(2016, 8, 10, 12, 28), u'WebRTC: Networking', u'(firefox48 fixed', u' firefox49 fixed', u' relnote-firefox 48+', u' firefox50 fixed', u' firefox51 fixed)']]]"]
# ["datetime.datetime(2016, 1, 20, 0, 3), datetime.datetime(2016, 2, 10, 9, 27), u'Libraries', u'(firefox46 wontfix', u' firefox47 fixed']", " datetime.datetime(2015, 9, 18, 15, 28), datetime.datetime(2016, 2, 4, 18, 8), u'Libraries', u'(firefox41 wontfix', u' firefox42+ wontfix', u' firefox43+ wontfix', u' firefox44+ wontfix', u' firefox45 wontfix', u' firefox46 wontfix', u' firefox47 fixed']", " datetime.datetime(2015, 11, 4, 9, 3), datetime.datetime(2016, 2, 5, 2, 40), u'Libraries', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47 fixed']", " datetime.datetime(2016, 1, 19, 23, 18), datetime.datetime(2016, 1, 29, 18, 20), u'Libraries', u'(firefox46 wontfix', u' firefox47 fixed']]]"]
# ["datetime.datetime(2013, 8, 23, 17, 6), datetime.datetime(2016, 2, 24, 0, 44), u'DOM: Security', u'(firefox22 wontfix', u' firefox23 affected', u' firefox24 affected', u' firefox25 affected', u' firefox26 affected', u' firefox47 fixed)']]]"]
# ["datetime.datetime(2014, 6, 13, 14, 1), datetime.datetime(2016, 3, 30, 14, 11), u'CSS Parsing and Computation', u'(firefox33 wontfix', u' firefox46 wontfix', u' firefox47 fixed', u' firefox48 fixed)']]]"]
# ["datetime.datetime(2016, 4, 4, 13, 0), datetime.datetime(2016, 4, 6, 17, 4), u'DOM', u'(firefox45 wontfix', u' firefox46+ wontfix', u' firefox47+ verified', u' firefox48+ verified']]]"]
# ["datetime.datetime(2016, 3, 9, 20, 1), datetime.datetime(2016, 5, 25, 12, 28), u'Tabbed Browser', u'(firefox46 wontfix', u' firefox47+ wontfix', u' firefox48+ verified', u' firefox49+ verified', u' firefox50 verified)']]]"]
# ["datetime.datetime(2016, 2, 14, 21, 50), datetime.datetime(2016, 2, 17, 2, 46), u'Device Permissions', u'(firefox47 verified', u' firefox48 fixed', u' firefox49 verified)']]]"]
# ["datetime.datetime(2015, 11, 11, 7, 15), datetime.datetime(2015, 11, 11, 8, 19), u'Graphics', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44 wontfix', u' firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49 fix-optional', u' firefox50 wontfix)']]]"]
# ["datetime.datetime(2016, 7, 25, 3, 41), datetime.datetime(2016, 8, 9, 5, 33), u'DOM: Security', u'(firefox48 wontfix', u' firefox49+ verified', u' firefox50+ verified)']]]"]
# ["datetime.datetime(2016, 1, 6, 2, 52), datetime.datetime(2016, 4, 14, 9, 55), u'Application Update', u'(firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']]]"]
# ["datetime.datetime(2015, 8, 10, 16, 43), datetime.datetime(2016, 2, 17, 12, 13), u'DOM', u'(firefox47 fixed)']]]"]
# ["datetime.datetime(2016, 2, 16, 5, 59), datetime.datetime(2016, 5, 25, 7, 16), u'Canvas: WebGL', u'(firefox44 wontfix', u' firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ verified', u' firefox48+ verified', u' firefox49+ verified']]]"]
# ["datetime.datetime(2016, 5, 16, 6, 23), datetime.datetime(2016, 5, 18, 8, 20), u'General', u'(firefox47 verified', u' firefox48 verified', u' firefox49 verified']]]"]
# ["datetime.datetime(2016, 5, 9, 15, 16), datetime.datetime(2016, 5, 10, 10, 44), u'DOM', u'(firefox46 wontfix', u' firefox47+ verified', u' firefox48+ verified', u' firefox49+ verified']]]"]
# ["datetime.datetime(2013, 5, 10, 10, 14), datetime.datetime(2016, 3, 3, 4, 2), u'Client: Desktop', u'(firefox44 wontfix', u' firefox45 wontfix', u' firefox46 fixed', u' firefox47 fixed)']]]"]
# ["datetime.datetime(2016, 5, 4, 22, 56), datetime.datetime(2016, 5, 15, 7, 31), u'HTML: Parser', u'(firefox46 wontfix', u' firefox47+ verified', u' firefox48+ verified', u' firefox49+ verified']]]"]
# ["datetime.datetime(2016, 5, 16, 10, 26), datetime.datetime(2016, 5, 16, 10, 49), u'DOM: Core & HTML', u'(firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']", " datetime.datetime(2016, 5, 3, 5, 39), datetime.datetime(2016, 5, 3, 12, 48), u'JavaScript Engine', u'(firefox46 wontfix', u' firefox47 verified', u' firefox48 verified', u' firefox49 verified']", " datetime.datetime(2016, 4, 3, 23, 54), datetime.datetime(2016, 5, 13, 13, 55), u'Layout: View Rendering', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49 fixed']", " datetime.datetime(2016, 4, 9, 7, 43), datetime.datetime(2016, 4, 15, 9, 30), u'WebRTC: Audio/Video', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 4, 14, 2, 21), datetime.datetime(2016, 5, 16, 2, 57), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ verified', u' firefox49 verified']", " datetime.datetime(2016, 4, 18, 16, 22), datetime.datetime(2016, 5, 10, 17, 31), u'Layout: View Rendering', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']", " datetime.datetime(2016, 4, 24, 23, 9), datetime.datetime(2016, 5, 10, 1, 54), u'Networking', u'(firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']", " datetime.datetime(2016, 3, 15, 14, 0), datetime.datetime(2016, 3, 15, 14, 0), u'Spelling checker', u'(firefox46 wontfix', u' firefox47 fixed', u' firefox48 fixed', u' firefox49 fixed']", " datetime.datetime(2016, 3, 31, 16, 17), datetime.datetime(2016, 5, 10, 17, 40), u'Layout', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ fixed', u' firefox48 fixed']", " datetime.datetime(2016, 3, 15, 10, 50), datetime.datetime(2016, 3, 15, 10, 50), u'Spelling checker', u'(firefox47 fixed', u' firefox48 fixed', u' firefox49 fixed']", " datetime.datetime(2016, 3, 14, 17, 15), datetime.datetime(2016, 3, 14, 17, 15), u'Spelling checker', u'(firefox46 wontfix', u' firefox47 fixed', u' firefox48 fixed', u' firefox49 fixed']", " datetime.datetime(2015, 12, 21, 1, 23), datetime.datetime(2016, 5, 1, 23, 15), u'JavaScript Engine: JIT', u'(firefox45 wontfix', u' firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']", " datetime.datetime(2016, 5, 17, 17, 25), datetime.datetime(2016, 5, 17, 18, 55), u'Graphics: Layers', u'(firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']]]"]
# ["datetime.datetime(2015, 11, 24, 2, 44), datetime.datetime(2016, 2, 25, 9, 25), u'WebExtensions: Untriaged', u'(firefox44 wontfix', u' firefox45+ wontfix', u' firefox46+ verified', u' firefox47+ verified', u' firefox48 verified']]]"]
# ["datetime.datetime(2015, 11, 11, 2, 58), datetime.datetime(2015, 12, 3, 14, 37), u'DOM: Security', u'(firefox45 wontfix', u' firefox46 verified']]]"]
# ["datetime.datetime(2016, 2, 3, 19, 46), datetime.datetime(2016, 3, 9, 8, 53), u'Developer Tools: Performance Tools (Profiler/Timeline)', u'(firefox45 wontfix', u' firefox46+ wontfix', u' firefox47+ fixed', u' firefox48 fixed)']", " datetime.datetime(2016, 4, 13, 7, 40), datetime.datetime(2016, 6, 2, 2, 35), u'JavaScript Engine', u'(firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']", " datetime.datetime(2016, 1, 27, 10, 45), datetime.datetime(2016, 3, 31, 7, 31), u'Graphics: Layers', u' firefox46- wontfix', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 1, 22, 6, 42), datetime.datetime(2016, 2, 1, 10, 5), u'Networking: DNS', u'(firefox47 fixed)']", " datetime.datetime(2016, 1, 25, 16, 25), datetime.datetime(2016, 1, 27, 12, 16), u'JavaScript Engine', u'(firefox46 wontfix', u' firefox47 verified']", " datetime.datetime(2016, 5, 7, 2, 6), datetime.datetime(2016, 5, 10, 10, 43), u'JavaScript Engine: JIT', u'(firefox46 wontfix', u' firefox47+ fixed', u' firefox48+ fixed', u' firefox49+ fixed']]]"]
# ["datetime.datetime(2016, 3, 8, 14, 51), datetime.datetime(2016, 3, 15, 22, 44), u'Audio/Video: Playback', u'(firefox45 wontfix', u' firefox46+ verified', u' firefox47+ verified', u' firefox48+ verified']]]"]
# ["datetime.datetime(2015, 8, 24, 10, 38), datetime.datetime(2016, 2, 17, 12, 20), u'DOM: Device Interfaces', u'(firefox41 wontfix', u' firefox42+ wontfix', u' firefox43+ wontfix', u' firefox44- wontfix', u' firefox45- wontfix', u' firefox46- fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 4, 4, 2, 27), datetime.datetime(2016, 4, 5, 11, 0), u'DOM: Service Workers', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ verified']]]"]
# ["datetime.datetime(2016, 2, 29, 18, 0), datetime.datetime(2016, 3, 14, 12, 37), u'DOM: Service Workers', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ verified', u' firefox48+ fixed']]]"]
# ["datetime.datetime(2015, 12, 2, 0, 17), datetime.datetime(2015, 12, 17, 15, 31), u'Data Providers', u'(firefox46 fixed']]]"]
# ["datetime.datetime(2015, 10, 8, 10, 4), datetime.datetime(2015, 12, 21, 13, 25), u'Application Update', u'(firefox45 wontfix', u' firefox46 verified']]]"]
# ["datetime.datetime(2016, 2, 4, 19, 28), datetime.datetime(2016, 3, 25, 15, 6), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']]]"]
# ["datetime.datetime(2016, 3, 8, 22, 42), datetime.datetime(2016, 3, 20, 15, 28), u'WebRTC: Audio/Video', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 3, 8, 10, 24), datetime.datetime(2016, 3, 18, 9, 30), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 3, 7, 8, 25), datetime.datetime(2016, 4, 1, 13, 56), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ verified', u' firefox48+ verified']", " datetime.datetime(2016, 3, 1, 16, 51), datetime.datetime(2016, 4, 15, 14, 28), u'JavaScript Engine', u'(firefox44 wontfix', u' firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ verified']", " datetime.datetime(2015, 7, 24, 11, 40), datetime.datetime(2016, 3, 4, 12, 21), u'ImageLib', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']]]"]
# ["datetime.datetime(2016, 3, 29, 7, 39), datetime.datetime(2016, 3, 29, 10, 54), u'DOM: Workers', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 3, 20, 16, 4), datetime.datetime(2016, 3, 21, 12, 18), u'XPCOM', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 3, 12, 17, 58), datetime.datetime(2016, 3, 14, 21, 2), u'Audio/Video: GMP', u'(firefox45 wontfix', u' firefox46blocking fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 3, 11, 19, 5), datetime.datetime(2016, 3, 15, 12, 23), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2016, 3, 7, 6, 36), datetime.datetime(2016, 3, 22, 0, 46), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ verified']", " datetime.datetime(2016, 3, 2, 16, 3), datetime.datetime(2016, 3, 22, 20, 57), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ verified', u' firefox48+ verified']", " datetime.datetime(2016, 2, 28, 3, 29), datetime.datetime(2016, 4, 20, 15, 5), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ verified']", " datetime.datetime(2016, 1, 25, 17, 29), datetime.datetime(2016, 3, 22, 20, 9), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ verified', u' firefox48+ verified']", " datetime.datetime(2016, 1, 25, 11, 51), datetime.datetime(2016, 2, 26, 9, 1), u'Graphics: Layers', u'(firefox45 wontfix', u' firefox46+ verified', u' firefox47+ verified', u' firefox48+ verified']", " datetime.datetime(2016, 1, 11, 8, 2), datetime.datetime(2016, 2, 7, 12, 24), u'JavaScript Engine', u'(firefox44 wontfix', u' firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ verified']", " datetime.datetime(2015, 10, 7, 6, 44), datetime.datetime(2016, 3, 10, 10, 17), u'JavaScript Engine', u'(firefox44 wontfix', u' firefox45+ wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48 fixed']", " datetime.datetime(2015, 11, 29, 13, 37), datetime.datetime(2016, 4, 14, 14, 56), u'DOM', u'(firefox43+ wontfix', u' firefox44+ wontfix', u' firefox45+ wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2015, 12, 11, 5, 53), datetime.datetime(2015, 12, 11, 12, 59), u'Disability Access APIs', u'(firefox45 wontfix', u' firefox46 fixed']]]"]
# ["datetime.datetime(2016, 2, 17, 17, 37), datetime.datetime(2016, 2, 17, 17, 44), u'JavaScript: GC', u'(firefox44 wontfix', u' firefox45 wontfix', u' firefox46 fixed', u' firefox47 fixed)']", " datetime.datetime(2015, 12, 2, 10, 2), datetime.datetime(2015, 12, 4, 10, 5), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46 verified']", " datetime.datetime(2016, 1, 19, 12, 28), datetime.datetime(2016, 6, 3, 4, 10), u'JavaScript Engine', u'(firefox45 wontfix', u' firefox46 verified']", " datetime.datetime(2016, 3, 9, 21, 30), datetime.datetime(2016, 3, 10, 14, 13), u'DOM: Service Workers', u'(firefox45 wontfix', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48+ fixed']", " datetime.datetime(2015, 3, 9, 18, 13), datetime.datetime(2017, 1, 5, 9, 3), u'JavaScript Engine', u'(firefox39 affected', u' firefox45 wontfix', u' firefox46 verified']", " datetime.datetime(2015, 4, 16, 11, 54), datetime.datetime(2015, 12, 29, 12, 1), u'XUL', u'(firefox40 affected', u' firefox46 fixed']]]"]
# ["datetime.datetime(2016, 2, 16, 15, 48), datetime.datetime(2016, 2, 16, 15, 49), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 2, 20, 12, 53), datetime.datetime(2016, 2, 20, 12, 54), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 2, 18, 9, 59), datetime.datetime(2016, 2, 18, 9, 59), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 2, 17, 11, 15), datetime.datetime(2016, 2, 17, 11, 17), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2016, 2, 16, 15, 56), datetime.datetime(2016, 2, 16, 19, 41), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 1, 28, 10, 31), datetime.datetime(2016, 1, 29, 9, 4), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 1, 28, 10, 5), datetime.datetime(2016, 1, 29, 9, 5), u'Graphics: Text', u'(firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2016, 1, 27, 16, 57), datetime.datetime(2016, 1, 29, 9, 11), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 1, 27, 13, 24), datetime.datetime(2016, 1, 29, 13, 48), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 1, 27, 12, 53), datetime.datetime(2016, 2, 17, 13, 57), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 1, 27, 11, 32), datetime.datetime(2016, 2, 16, 9, 37), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 1, 27, 10, 57), datetime.datetime(2016, 1, 29, 9, 36), u'Graphics: Text', u'(firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2016, 1, 27, 10, 43), datetime.datetime(2016, 1, 29, 9, 51), u'Graphics: Text', u'(firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2015, 7, 17, 10, 39), datetime.datetime(2016, 3, 1, 6, 4), u'Libraries', u'(firefox39 wontfix', u' firefox40 wontfix', u' firefox41+ wontfix', u' firefox42- wontfix', u' firefox43- wontfix', u' firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2015, 9, 29, 8, 6), datetime.datetime(2016, 3, 1, 6, 3), u'Libraries', u'(firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed']]]"]
# ["datetime.datetime(2016, 2, 16, 23, 57), datetime.datetime(2016, 2, 24, 13, 7), u'Graphics: Text', u'(firefox44 wontfix', u' firefox45 fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2015, 6, 19, 11, 52), datetime.datetime(2015, 11, 2, 12, 11), u'WebRTC', u'(firefox45 fixed)']]]"]
# ["datetime.datetime(2015, 12, 5, 10, 25), datetime.datetime(2016, 1, 19, 7, 32), u'WebRTC: Audio/Video', u'(firefox43 wontfix', u' firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2015, 11, 25, 12, 51), datetime.datetime(2016, 1, 21, 10, 57), u'HTML: Parser', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2015, 10, 28, 10, 31), datetime.datetime(2016, 2, 29, 19, 32), u'WebRTC: Audio/Video', u'(firefox43 wontfix', u' firefox44+ wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2015, 10, 24, 14, 15), datetime.datetime(2015, 11, 12, 17, 45), u'Audio/Video', u'(firefox44 wontfix', u' firefox45 fixed)']]]"]
# ["datetime.datetime(2015, 10, 22, 17, 30), datetime.datetime(2017, 3, 29, 0, 35), u'WebRTC: Audio/Video', u'(firefox41 wontfix', u' firefox44 wontfix', u' firefox45 fixed', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2015, 10, 20, 18, 13), datetime.datetime(2015, 11, 4, 9, 33), u'WebRTC: Networking', u'(firefox41 wontfix', u' firefox42- wontfix', u' firefox43 affected', u' firefox44 affected', u' firefox45 fixed']]]"]
# ["datetime.datetime(2016, 1, 24, 20, 52), datetime.datetime(2016, 1, 24, 20, 54), u'Graphics: Text', u'(firefox44- wontfix', u' firefox45+ verified', u' firefox46+ verified', u' firefox47+ verified']]]"]
# ["datetime.datetime(2016, 2, 8, 12, 18), datetime.datetime(2016, 2, 8, 12, 18), u'Networking: HTTP', u'(firefox45 fixed', u' firefox46 fixed']]]"]
# ["datetime.datetime(2016, 2, 9, 7, 44), datetime.datetime(2016, 3, 2, 14, 54), u'Session Restore', u'(firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2016, 2, 4, 18, 47), datetime.datetime(2016, 2, 16, 19, 37), u'Plug-ins', u'(firefox44- wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2016, 2, 2, 13, 24), datetime.datetime(2016, 2, 15, 5, 23), u'Address Bar', u'(firefox45 verified', u' firefox46 verified', u' firefox47 verified']]]"]
# ["datetime.datetime(2016, 1, 27, 3, 6), datetime.datetime(2016, 2, 1, 4, 1), u'XSLT', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46+ verified', u' firefox47+ verified']]]"]
# ["datetime.datetime(2016, 1, 10, 21, 32), datetime.datetime(2016, 2, 22, 11, 5), u'DOM', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44 wontfix', u' firefox45 verified', u' firefox46 verified', u' firefox47 verified']]]"]
# ["datetime.datetime(2016, 1, 19, 7, 24), datetime.datetime(2016, 2, 18, 21, 33), u'WebRTC: Networking', u'(firefox43 wontfix', u' firefox44 wontfix', u' firefox45+ verified', u' firefox46+ verified', u' firefox47+ verified']]]"]
# ["datetime.datetime(2016, 2, 18, 11, 32), datetime.datetime(2016, 2, 19, 11, 8), u'DOM', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46+ verified', u' firefox47+ verified']]]"]
# ["datetime.datetime(2016, 2, 4, 16, 12), datetime.datetime(2016, 2, 8, 2, 12), u'HTML: Parser', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46+ fixed', u' firefox47+ verified']]]"]
# ["datetime.datetime(2015, 12, 23, 14, 34), datetime.datetime(2016, 1, 24, 16, 40), u'DOM: Service Workers', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ verified']]]"]
# ["datetime.datetime(2015, 11, 28, 8, 52), datetime.datetime(2016, 2, 24, 8, 42), u'Address Bar', u'(firefox45 verified', u' firefox46 verified', u' firefox47 verified)']]]"]
# ["datetime.datetime(2015, 11, 23, 1, 22), datetime.datetime(2015, 11, 23, 1, 48), u'Audio/Video: Playback', u'(firefox45 fixed)']]]"]
# ["datetime.datetime(2015, 8, 29, 7, 25), datetime.datetime(2016, 1, 11, 6, 50), u'Canvas: WebGL', u'(firefox43 wontfix', u' firefox44 wontfix', u' firefox45 fixed', u' firefox46 fixed)']]]"]
# ["datetime.datetime(2015, 9, 27, 22, 5), datetime.datetime(2016, 1, 13, 15, 40), u'DOM: Security', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46 verified']]]"]
# ["datetime.datetime(2016, 1, 26, 14, 19), datetime.datetime(2016, 1, 27, 16, 8), u'DOM: Security', u'(firefox44 wontfix', u' firefox45 verified', u' firefox46 fixed', u' firefox47 fixed']]]"]
# ["datetime.datetime(2016, 2, 16, 15, 3), datetime.datetime(2016, 2, 16, 17, 33), u'DOM', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2016, 2, 10, 4, 16), datetime.datetime(2016, 2, 11, 23, 37), u'WebRTC: Audio/Video', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2016, 2, 4, 8, 4), datetime.datetime(2016, 2, 15, 10, 21), u'Networking: DNS', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46+ fixed', u' firefox47+ verified']", " datetime.datetime(2016, 1, 27, 16, 10), datetime.datetime(2016, 1, 29, 12, 6), u'DOM: Animation', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46+ fixed', u' firefox47+ verified']", " datetime.datetime(2016, 1, 27, 14, 45), datetime.datetime(2016, 2, 2, 14, 59), u'DOM: Events', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2015, 9, 24, 0, 16), datetime.datetime(2016, 1, 21, 10, 55), u'ImageLib', u'(firefox42 unaffected', u' firefox43+ wontfix', u' firefox44+ wontfix', u' firefox45+ verified', u' firefox46+ verified']", " datetime.datetime(2015, 11, 12, 14, 30), datetime.datetime(2015, 12, 2, 15, 16), u'Audio/Video: Playback', u'(firefox45 fixed']", " datetime.datetime(2015, 11, 12, 14, 38), datetime.datetime(2015, 12, 2, 15, 5), u'Audio/Video: Playback', u'(firefox45 fixed']", " datetime.datetime(2015, 11, 12, 14, 47), datetime.datetime(2015, 11, 22, 19, 47), u'Audio/Video: Playback', u'(firefox45 fixed']", " datetime.datetime(2015, 11, 17, 13, 11), datetime.datetime(2015, 11, 17, 13, 56), u'XPCOM', u'(firefox42 wontfix', u' firefox43 affected', u' firefox44 affected', u' firefox45 fixed']", " datetime.datetime(2015, 12, 21, 18, 33), datetime.datetime(2016, 1, 5, 6, 50), u'JavaScript Engine', u'(firefox42 unaffected', u' firefox43 wontfix', u' firefox44+ wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47 verified']", " datetime.datetime(2016, 1, 4, 6, 5), datetime.datetime(2016, 1, 14, 13, 53), u'JavaScript Engine', u'(firefox45 verified', u' firefox46 verified)']", " datetime.datetime(2016, 1, 11, 7, 0), datetime.datetime(2016, 1, 27, 16, 19), u'ImageLib', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2016, 1, 12, 5, 55), datetime.datetime(2016, 1, 15, 7, 51), u'JavaScript Engine', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44- wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ verified']", " datetime.datetime(2015, 8, 27, 3, 56), datetime.datetime(2015, 9, 7, 11, 35), u'JavaScript Engine', u'(firefox42 unaffected', u' firefox43 verified', u' firefox45 verified']", " datetime.datetime(2016, 1, 21, 17, 49), datetime.datetime(2016, 3, 7, 7, 24), u'JavaScript Engine', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46+ verified', u' firefox47+ verified']", " datetime.datetime(2015, 9, 15, 20, 55), datetime.datetime(2015, 9, 23, 3, 51), u'XSLT', u'(firefox43 affected', u' firefox45 fixed)']]]"]
# ["datetime.datetime(2016, 2, 19, 9, 31), datetime.datetime(2016, 2, 23, 11, 21), u'DOM', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2016, 2, 1, 20, 38), datetime.datetime(2016, 2, 11, 8, 21), u'DOM', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2016, 1, 29, 12, 8), datetime.datetime(2016, 1, 29, 14, 22), u'CSS Parsing and Computation', u'(firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2016, 1, 24, 11, 39), datetime.datetime(2016, 1, 26, 5, 53), u'JavaScript Engine', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']", " datetime.datetime(2016, 1, 20, 10, 34), datetime.datetime(2016, 9, 22, 14, 48), u'Layout', u'(firefox45+ fixed', u' firefox46+ fixed']", " datetime.datetime(2015, 12, 22, 8, 52), datetime.datetime(2016, 4, 25, 7, 6), u'WebRTC: Networking', u'(firefox42 wontfix', u' firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed', u' firefox48 fixed', u' firefox49+ fixed']", " datetime.datetime(2015, 11, 15, 18, 30), datetime.datetime(2016, 1, 26, 19, 15), u'ImageLib', u'(firefox44 wontfix', u' firefox45+ verified', u' firefox46+ verified', u' firefox47+ verified']", " datetime.datetime(2015, 11, 4, 21, 25), datetime.datetime(2016, 2, 12, 8, 41), u'JavaScript Engine: JIT', u'(firefox44 wontfix', u' firefox45+ wontfix', u' firefox46+ fixed', u' firefox47+ verified', u' firefox48 affected', u' firefox49 affected', u' firefox50 affected)']", " datetime.datetime(2015, 1, 20, 5, 41), datetime.datetime(2016, 9, 22, 14, 48), u'JavaScript Engine', u'(firefox45 fixed', u' firefox46 verified']]]"]
# ["datetime.datetime(2016, 2, 3, 8, 18), datetime.datetime(2016, 2, 18, 13, 59), u'Libraries', u'(firefox44 wontfix', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2016, 2, 3, 17, 43), datetime.datetime(2016, 2, 9, 9, 32), u'DOM: Service Workers', u'(firefox44+ verified', u' firefox45+ fixed', u' firefox46+ fixed', u' firefox47+ fixed']]]"]
# ["datetime.datetime(2015, 12, 30, 11, 41), datetime.datetime(2015, 12, 30, 12, 2), u'General', u'(firefox44 fixed', u' firefox45 fixed', u' firefox46 fixed']]]"]
# ["datetime.datetime(2016, 1, 5, 15, 32), datetime.datetime(2016, 1, 12, 2, 58), u'Safe Browsing', u'(firefox42 unaffected', u' firefox43+ affected', u' firefox44+ verified', u' firefox45+ verified', u' firefox46+ verified)']]]"]
# ["datetime.datetime(2015, 12, 11, 17, 21), datetime.datetime(2015, 12, 20, 6, 37), u'Audio/Video: Playback', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ verified', u' firefox45+ verified', u' firefox46+ verified']]]"]
# ["datetime.datetime(2015, 10, 14, 11, 9), datetime.datetime(2015, 10, 15, 9, 1), u'Networking: JAR', u'(firefox44 fixed)']]]"]
# ["datetime.datetime(2015, 7, 22, 13, 42), datetime.datetime(2016, 7, 2, 11, 29), u'Graphics', u'(firefox42 wontfix', u' firefox43+ wontfix', u' firefox44+ fixed']]]"]
# ["datetime.datetime(2015, 11, 27, 6, 47), datetime.datetime(2016, 1, 5, 17, 25), u'General', u'(firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ fixed']]]"]
# ["datetime.datetime(2015, 7, 29, 14, 44), datetime.datetime(2015, 10, 31, 1, 30), u'Address Bar', u'(firefox44 fixed)']]]"]
# ["datetime.datetime(2014, 12, 29, 21, 34), datetime.datetime(2015, 10, 8, 16, 18), u'Downloads API', u'(firefox44 fixed)']]]"]
# ["datetime.datetime(2015, 9, 25, 9, 10), datetime.datetime(2016, 1, 4, 14, 44), u'General', u'(firefox44 fixed', u' firefox45 fixed', u' firefox46 fixed']]]"]
# ["datetime.datetime(2015, 12, 18, 10, 33), datetime.datetime(2016, 2, 18, 12, 13), u'Networking: Cookies', u'(firefox44 fixed', u' firefox45 fixed', u' firefox46 fixed)']]]"]
# ["datetime.datetime(2015, 8, 2, 21, 9), datetime.datetime(2016, 3, 1, 5, 57), u'Libraries', u'(firefox40 wontfix', u' firefox41 wontfix', u' firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ fixed']", " datetime.datetime(2015, 8, 14, 23, 56), datetime.datetime(2015, 8, 14, 23, 56), u'Libraries', ]]]"]
# ["datetime.datetime(2012, 2, 5, 2, 35), datetime.datetime(2015, 10, 7, 22, 49), u'XUL Widgets', u'(firefox44 verified)']]]"]
# ["datetime.datetime(2015, 11, 1, 1, 58), datetime.datetime(2016, 1, 20, 0, 19), u'Canvas: WebGL', u'(firefox42 wontfix', u' firefox43+ wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46 fixed']]]"]
# ["datetime.datetime(2015, 12, 10, 11, 19), datetime.datetime(2015, 12, 15, 10, 48), u'ImageLib', ]]]"]
# ["datetime.datetime(2015, 12, 22, 8, 44), datetime.datetime(2017, 2, 9, 7, 53), u'WebRTC', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44 wontfix', u' firefox45 fixed', u' firefox46 fixed']", " datetime.datetime(2015, 12, 8, 6, 50), datetime.datetime(2015, 12, 15, 11, 0), u'ImageLib', u'(firefox42 unaffected', u' firefox43+ wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ verified']", " datetime.datetime(2015, 12, 2, 8, 54), datetime.datetime(2015, 12, 22, 8, 22), u'ImageLib', u'(firefox42 unaffected', u' firefox43+ wontfix', u' firefox44+ verified', u' firefox45+ verified', u' firefox46+ verified']", " datetime.datetime(2015, 11, 5, 6, 55), datetime.datetime(2016, 7, 2, 11, 32), u'Autocomplete', u'(firefox42 wontfix', u' firefox43- wontfix', u' firefox44+ fixed', u' firefox45+ fixed']", " datetime.datetime(2015, 9, 29, 8, 6), datetime.datetime(2016, 3, 1, 6, 3), u'Libraries', u'(firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed']", " datetime.datetime(2015, 9, 28, 18, 30), datetime.datetime(2015, 9, 28, 18, 31), u'Layout: Text', u'(firefox41 unaffected', u' firefox42 unaffected', u' firefox43 unaffected', u' firefox44 fixed']", " datetime.datetime(2015, 9, 28, 18, 25), datetime.datetime(2015, 9, 28, 18, 25), u'Layout: Text', u'(firefox41 wontfix', u' firefox42 wontfix', u' firefox43 wontfix', u' firefox44 fixed']", " datetime.datetime(2015, 9, 28, 17, 49), datetime.datetime(2015, 9, 28, 17, 50), u'Layout: Text', u'(firefox41 wontfix', u' firefox42 wontfix', u' firefox43 wontfix', u' firefox44 fixed']", " datetime.datetime(2015, 7, 2, 18, 2), datetime.datetime(2015, 10, 6, 8, 12), u'JavaScript Engine', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44 fixed', u' firefox45 verified)']", " datetime.datetime(2015, 7, 23, 10, 18), datetime.datetime(2015, 10, 27, 8, 16), u'JavaScript Engine', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44 fixed', u' firefox45 verified)']", " datetime.datetime(2015, 9, 22, 12, 43), datetime.datetime(2015, 9, 28, 10, 22), u'Networking: HTTP', u'(firefox43 wontfix', u' firefox44 fixed']", " datetime.datetime(2015, 9, 28, 18, 20), datetime.datetime(2015, 9, 28, 18, 22), u'Layout: Text', u'(firefox41 wontfix', u' firefox42 wontfix', u' firefox43 wontfix', u' firefox44 fixed']", " datetime.datetime(2015, 9, 21, 4, 12), datetime.datetime(2015, 9, 21, 4, 12), u'JavaScript Engine', u'(firefox43 wontfix', u' firefox44 fixed']]]"]
# ["datetime.datetime(2015, 12, 22, 8, 38), datetime.datetime(2015, 12, 30, 10, 21), u'WebRTC', u'(firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ fixed']", " datetime.datetime(2015, 12, 21, 10, 43), datetime.datetime(2016, 1, 14, 11, 45), u'JavaScript Engine', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ verified', u' firefox45+ verified', u' firefox46+ verified']", " datetime.datetime(2015, 12, 18, 18, 43), datetime.datetime(2015, 12, 31, 4, 46), u'JavaScript Engine', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ verified', u' firefox46+ verified']", " datetime.datetime(2015, 12, 17, 1, 19), datetime.datetime(2015, 12, 17, 15, 9), u'WebRTC: Networking', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46 unaffected']", " datetime.datetime(2015, 12, 16, 10, 56), datetime.datetime(2015, 12, 17, 7, 43), u'JavaScript Engine', u'(firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ verified', u' firefox46+ verified']", " datetime.datetime(2015, 12, 4, 15, 19), datetime.datetime(2016, 1, 4, 10, 49), u'Canvas: 2D', u'(firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ fixed']", " datetime.datetime(2015, 12, 4, 1, 58), datetime.datetime(2015, 12, 23, 21, 14), u'Audio/Video: Playback', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ verified', u' firefox45+ verified', u' firefox46+ verified']", " datetime.datetime(2015, 12, 4, 11, 28), datetime.datetime(2015, 12, 4, 22, 10), u'CSS Parsing and Computation', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46 fixed']", " datetime.datetime(2015, 12, 4, 13, 1), datetime.datetime(2016, 1, 6, 10, 47), u'CSS Parsing and Computation', u'(firefox43 wontfix', u' firefox44+ verified', u' firefox45+ verified', u' firefox46+ verified']", " datetime.datetime(2015, 11, 12, 6, 14), datetime.datetime(2016, 1, 19, 22, 28), u'ImageLib', u'(firefox42 wontfix', u' firefox43+ wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ verified']", " datetime.datetime(2015, 11, 3, 18, 6), datetime.datetime(2015, 11, 6, 4, 48), u'JavaScript Engine', u'(firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ fixed']", " datetime.datetime(2015, 11, 10, 21, 54), datetime.datetime(2015, 12, 29, 13, 50), u'Audio/Video: MediaStreamGraph', u'(firefox42 wontfix', u' firefox43 wontfix', u' firefox44+ fixed', u' firefox45+ fixed', u' firefox46+ fixed']]]"]
# [']']
# ["datetime.datetime(2016, 1, 5, 6, 21), datetime.datetime(2016, 5, 17, 16, 1), u'XML', u'(firefox46 wontfix', u' firefox47+ wontfix', u' firefox48+ fixed', u' firefox49+ fixed']]]"]
# [']']
# ["datetime.datetime(2015, 4, 25, 7, 54), datetime.datetime(2015, 12, 15, 14, 6), u'Libraries', u'(firefox39 wontfix', u' firefox40- wontfix', u' firefox41+ wontfix', u' firefox42+ wontfix', u' firefox43+ fixed', u' firefox44+ fixed', u' firefox45+ fixed']]]"]
# ["datetime.datetime(2015, 4, 12, 13, 45), datetime.datetime(2015, 4, 12, 14, 20), u'DOM', u'(firefox40 wontfix', u' firefox41 fixed', u' firefox42 fixed']", " datetime.datetime(2015, 5, 21, 19, 58), datetime.datetime(2015, 7, 7, 8, 25), u'DOM', u'(firefox40 wontfix', u' firefox41+ fixed', u' firefox42 fixed']]]"]
# ["datetime.datetime(2015, 11, 19, 16, 1), datetime.datetime(2015, 11, 25, 15, 53), u'WebExtensions: Untriaged', u'(firefox42 wontfix', u' firefox43+ fixed', u' firefox44+ fixed', u' firefox45+ fixed']]]"]
# ["datetime.datetime(2015, 10, 20, 14, 0), datetime.datetime(2015, 12, 1, 19, 54), u'Audio/Video: Playback', u'(firefox42 wontfix', u' firefox43+ fixed', u' firefox44+ fixed', u' firefox45+ fixed']]]"]
# ["datetime.datetime(2015, 8, 27, 11, 58), datetime.datetime(2015, 9, 4, 12, 27), u'XPCOM', u'(firefox43 fixed']]]"]
# ["datetime.datetime(2015, 6, 27, 12, 52), datetime.datetime(2015, 7, 15, 6, 59), u'JavaScript Engine', u'(firefox41 wontfix', u' firefox42 wontfix', u' firefox43 fixed']]]"]
# ["datetime.datetime(2015, 8, 14, 11, 40), datetime.datetime(2015, 8, 18, 12, 36), u'Networking: HTTP', u'(firefox42 wontfix', u' firefox43 fixed']]]"]
# ...
# ["datetime.datetime(2011, 7, 19, 6, 34), datetime.datetime(2011, 9, 30, 17, 10), u'Security', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed', u' firefox9+ fixed']]]"]
# ["datetime.datetime(2011, 5, 6, 15, 19), datetime.datetime(2011, 9, 19, 14, 0), u'Networking', u'(firefox5 wontfix', u' firefox6- wontfix', u' firefox7+ fixed']]]"]
# ["datetime.datetime(2011, 6, 20, 8, 12), datetime.datetime(2011, 8, 8, 17, 3), u'DOM', u'(firefox5 affected', u' firefox6 fixed', u' firefox7 fixed']]]"]
# ["datetime.datetime(2011, 9, 6, 3, 35), datetime.datetime(2011, 9, 6, 3, 38), u'JavaScript Engine', u'(firefox6 unaffected', u' firefox7 unaffected', u' firefox8 unaffected', u' firefox9 unaffected', u' firefox10 unaffected']]]"]
# ["datetime.datetime(2011, 8, 14, 6, 7), datetime.datetime(2011, 8, 14, 11, 37), u'DOM: Events', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed', u' firefox9+ fixed']", " datetime.datetime(2011, 7, 18, 20, 50), datetime.datetime(2011, 8, 31, 5, 25), u'JavaScript Engine', u'(firefox7 fixed', u' firefox8 fixed']", " datetime.datetime(2011, 7, 24, 0, 42), datetime.datetime(2011, 7, 24, 10, 6), u'Disability Access APIs', u'(firefox5 unaffected', u' firefox6 affected', u' firefox7 fixed', u' firefox8 fixed']", " datetime.datetime(2011, 7, 14, 20, 48), datetime.datetime(2011, 9, 22, 16, 9), u'Graphics', u'(firefox5- unaffected', u' firefox6 unaffected', u' firefox7+ fixed', u' firefox8+ fixed']", " datetime.datetime(2011, 7, 9, 0, 2), datetime.datetime(2011, 8, 29, 19, 7), u'XPConnect', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed', u' firefox9+ fixed']", " datetime.datetime(2011, 7, 4, 15, 56), datetime.datetime(2011, 7, 26, 17, 46), u'XPConnect', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed']", " datetime.datetime(2011, 7, 1, 19, 30), datetime.datetime(2011, 7, 8, 0, 54), u'Layout: Text', u'(firefox5 unaffected', u' firefox7+ fixed', u' firefox8 fixed']", " datetime.datetime(2011, 6, 27, 10, 15), datetime.datetime(2011, 7, 4, 8, 47), u'JavaScript Engine', u'(firefox5- unaffected', u' firefox6- unaffected', u' firefox7+ fixed']", " datetime.datetime(2011, 6, 24, 12, 10), datetime.datetime(2011, 6, 27, 10, 11), u'XPConnect', u'(firefox5 unaffected', u' firefox6 unaffected', u' firefox7 fixed']", " datetime.datetime(2011, 5, 14, 23, 18), datetime.datetime(2011, 6, 23, 10, 48), u'JavaScript Engine', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed']", " datetime.datetime(2011, 5, 22, 4, 42), datetime.datetime(2011, 5, 22, 8, 48), u'JavaScript Engine', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed']", " datetime.datetime(2011, 6, 2, 10, 17), datetime.datetime(2011, 6, 6, 11, 57), u'JavaScript Engine', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed']", " datetime.datetime(2011, 6, 16, 23, 27), datetime.datetime(2011, 8, 12, 12, 21), u'Graphics', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed', u' firefox9+ fixed']", " datetime.datetime(2010, 3, 12, 10, 57), datetime.datetime(2010, 3, 14, 9, 56), u'Plug-ins', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed']]]"]
# ["datetime.datetime(2010, 3, 25, 12, 24), datetime.datetime(2010, 3, 25, 13, 2), u'Widget: Cocoa', ]]]"]
# ["datetime.datetime(2011, 6, 5, 19, 42), datetime.datetime(2011, 9, 19, 12, 25), u'Networking', u'(firefox7 fixed']", " datetime.datetime(2011, 6, 19, 10, 19), datetime.datetime(2011, 8, 29, 11, 42), u'Graphics', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed', u' firefox9+ fixed']", " datetime.datetime(2011, 5, 5, 11, 41), datetime.datetime(2011, 8, 1, 14, 33), u'Plug-ins', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 5, 28, 8, 1), datetime.datetime(2011, 8, 24, 13, 42), u'XSLT', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed']]]"]
# ["datetime.datetime(2011, 5, 15, 19, 16), datetime.datetime(2011, 5, 19, 7, 30), u'Security', u'(firefox5- wontfix', u' firefox6+ fixed']]]"]
# ["datetime.datetime(2011, 7, 20, 7, 10), datetime.datetime(2011, 7, 21, 15, 24), u'Audio/Video', u'(firefox5 wontfix', u' firefox6+ fixed', u' firefox7+ fixed', u' firefox8+ fixed']]]"]
# ["datetime.datetime(2011, 5, 9, 0, 30), datetime.datetime(2011, 6, 23, 19, 23), u'JavaScript Engine', u'(firefox5- affected', u' firefox6+ fixed', u' firefox7+ fixed']]]"]
# ["datetime.datetime(2011, 6, 17, 5, 45), datetime.datetime(2011, 7, 18, 15, 26), u'DOM: Core & HTML', u'(firefox5- affected', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 8, 16, 20, 5), datetime.datetime(2011, 12, 5, 5, 14), u'Add-ons Manager', ]]]"]
# ["datetime.datetime(2011, 7, 25, 13, 38), datetime.datetime(2011, 7, 28, 13, 17), u'Canvas: WebGL', u'(firefox6 fixed', u' firefox7 fixed']]]"]
# ["datetime.datetime(2011, 6, 21, 9, 56), datetime.datetime(2011, 6, 29, 17, 5), u'Canvas: WebGL', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7+ fixed', u' firefox8 fixed']]]"]
# ["datetime.datetime(2011, 6, 21, 9, 47), datetime.datetime(2011, 6, 23, 8, 37), u'Canvas: WebGL', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7+ fixed']]]"]
# ["datetime.datetime(2011, 5, 9, 14, 27), datetime.datetime(2011, 10, 5, 8, 28), u'Canvas: 2D', u'(firefox5 affected', u' firefox6+ fixed', u' firefox7 affected', u' firefox8+ fixed', u' firefox9+ fixed', u' firefox10+ verified']]]"]
# ["datetime.datetime(2011, 7, 6, 3, 49), datetime.datetime(2011, 7, 6, 3, 57), u'SVG', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7+ fixed', u' firefox8+ fixed']", " datetime.datetime(2011, 4, 6, 22, 29), datetime.datetime(2011, 4, 11, 15, 26), u'XPConnect', u'(firefox5- affected', u' firefox6 fixed']", " datetime.datetime(2011, 6, 29, 10, 1), datetime.datetime(2011, 7, 8, 3, 17), u'Places', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 6, 27, 10, 30), datetime.datetime(2011, 7, 25, 16, 5), u'Layout', u'(firefox5- affected', u' firefox6+ fixed', u' firefox7+ fixed', u' firefox8+ fixed']", " datetime.datetime(2011, 6, 26, 11, 47), datetime.datetime(2011, 7, 4, 14, 1), u'XSLT', u'(firefox5 affected', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 6, 24, 15, 35), datetime.datetime(2011, 6, 30, 13, 58), u'Printing: Output', u'(firefox5 unaffected', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 6, 20, 5, 50), datetime.datetime(2011, 6, 20, 8, 12), u'Networking: WebSockets', u'(firefox6+ fixed']", " datetime.datetime(2011, 6, 5, 1, 14), datetime.datetime(2011, 6, 12, 12, 58), u'JavaScript Engine', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7+ fixed', u' firefox8+ fixed']", " datetime.datetime(2011, 5, 28, 23, 42), datetime.datetime(2011, 6, 16, 15, 50), u'JavaScript Engine', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7+ fixed', u' firefox8+ fixed']", " datetime.datetime(2011, 4, 18, 21, 26), datetime.datetime(2011, 5, 4, 9, 57), u'JavaScript Engine', u'(firefox5 unaffected', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 4, 17, 23, 10), datetime.datetime(2011, 6, 9, 17, 48), u'SVG', u'(firefox5- wontfix', u' firefox6+ fixed', u' firefox7 fixed']", " datetime.datetime(2011, 4, 15, 7, 14), datetime.datetime(2011, 4, 15, 7, 14), u'Security', u'(firefox5- wontfix', u' firefox6+ fixed']", " datetime.datetime(2011, 4, 15, 7, 12), datetime.datetime(2011, 5, 11, 16, 31), u'Security', u'(firefox5- wontfix', u' firefox6+ fixed']", " datetime.datetime(2011, 3, 31, 7, 10), datetime.datetime(2011, 7, 25, 11, 0), u'Canvas: WebGL', u'(firefox5 affected', u' firefox6+ fixed', u' firefox7+ fixed', u' firefox8+ fixed']]]"]
# ["datetime.datetime(2010, 6, 15, 8, 32), datetime.datetime(2011, 8, 1, 15, 4), u'Security', ]]]"]
# ["datetime.datetime(2011, 1, 16, 18, 0), datetime.datetime(2011, 4, 15, 16, 46), u'JavaScript Engine', u'(firefox7- unaffected', u' firefox8- unaffected', u' firefox9- unaffected']]]"]
# ["datetime.datetime(2010, 1, 21, 16, 20), datetime.datetime(2010, 3, 26, 16, 6), u'JavaScript Engine', ]", " datetime.datetime(2011, 3, 18, 18, 27), datetime.datetime(2011, 6, 1, 12, 52), u'XUL', u'(firefox5- unaffected', u' firefox6- unaffected', u' firefox7 unaffected']", " datetime.datetime(2011, 7, 27, 8, 36), datetime.datetime(2011, 7, 27, 14, 26), u'JavaScript Engine', u'(firefox5 unaffected', u' firefox6 unaffected', u' firefox7 unaffected', u' firefox8 unaffected', u' firefox9 unaffected', u' firefox10 unaffected']", " datetime.datetime(2011, 2, 7, 15, 4), datetime.datetime(2011, 7, 13, 17, 25), u'JavaScript Engine', ]", " datetime.datetime(2010, 12, 1, 13, 4), datetime.datetime(2011, 7, 27, 16, 0), u'JavaScript Engine', u'(firefox5- unaffected', u' firefox6- unaffected', u' firefox7- unaffected', u' firefox8- unaffected', u' firefox9- unaffected', u' firefox10- unaffected']]]"]
# ["datetime.datetime(2011, 4, 15, 6, 42), datetime.datetime(2011, 11, 9, 15, 21), u'Security', u'(firefox5 unaffected', u' firefox7- unaffected', u' firefox8- unaffected', u' firefox9- unaffected', u' firefox10- unaffected']", " datetime.datetime(2011, 3, 21, 9, 51), datetime.datetime(2011, 6, 6, 13, 47), u'Security', ]", " datetime.datetime(2010, 11, 22, 19, 31), datetime.datetime(2011, 6, 6, 13, 46), u'DOM', ]]]"]
# ["datetime.datetime(2011, 3, 17, 9, 7), datetime.datetime(2011, 7, 19, 12, 26), u'Document Navigation', ]]]"]
# ["datetime.datetime(2011, 3, 18, 17, 21), datetime.datetime(2011, 5, 10, 16, 49), u'Networking: Cookies', u'(firefox5 fixed']]]"]
# [']']
# ["datetime.datetime(2011, 4, 6, 11, 54), datetime.datetime(2011, 7, 22, 18, 52), u'DOM: Core & HTML', u'(firefox5- unaffected', u' firefox6- unaffected', u' firefox7- unaffected', u' firefox8- unaffected', u' firefox9- unaffected']]]"]
# ["datetime.datetime(2011, 3, 1, 22, 49), datetime.datetime(2011, 6, 13, 23, 45), u'General', u'(firefox5- fixed', u' firefox6- fixed', u' firefox7- fixed']", " datetime.datetime(2011, 3, 6, 6, 13), datetime.datetime(2011, 4, 8, 15, 57), u'ImageLib', u'(firefox5+ fixed', u' firefox6+ fixed']]]"]
# ["datetime.datetime(2011, 4, 18, 11, 31), datetime.datetime(2011, 5, 16, 15, 20), u'JavaScript Engine', u'(firefox5- unaffected', u' firefox6- unaffected', u' firefox7- unaffected']", " datetime.datetime(2011, 2, 18, 7, 10), datetime.datetime(2011, 2, 18, 18, 31), u'JavaScript Engine', ]]]"]
# ["datetime.datetime(2011, 4, 27, 14, 3), datetime.datetime(2011, 4, 29, 17, 57), u'SVG', u'(firefox5+ fixed', u' firefox6 fixed']", " datetime.datetime(2011, 5, 1, 13, 16), datetime.datetime(2011, 5, 11, 18, 14), u'SVG', u'(firefox5+ fixed', u' firefox6 fixed']", " datetime.datetime(2011, 4, 24, 1, 39), datetime.datetime(2011, 4, 29, 13, 59), u'Layout', u'(firefox5 fixed']", " datetime.datetime(2011, 4, 26, 18, 10), datetime.datetime(2011, 4, 27, 10, 31), u'JavaScript Engine', u'(firefox5+ fixed', u' firefox6+ fixed']", " datetime.datetime(2011, 4, 8, 20, 33), datetime.datetime(2011, 5, 6, 8, 40), u'Canvas: WebGL', u'(firefox5+ fixed']", " datetime.datetime(2011, 4, 6, 10, 18), datetime.datetime(2011, 6, 10, 16, 50), u'JavaScript Engine', u'(firefox5+ fixed', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 3, 22, 11, 47), datetime.datetime(2011, 4, 15, 21, 42), u'JavaScript Engine', u'(firefox5+ fixed']", " datetime.datetime(2010, 9, 16, 13, 11), datetime.datetime(2013, 12, 27, 14, 34), u'Security', u'(firefox5+ fixed', u' firefox6+ fixed']", " datetime.datetime(2011, 3, 22, 14, 52), datetime.datetime(2011, 3, 24, 14, 36), u'JavaScript Engine', u'(firefox5 fixed']]]"]
# ["datetime.datetime(2011, 3, 30, 15, 44), datetime.datetime(2011, 6, 3, 11, 15), u'DOM: Core & HTML', u'(firefox5+ fixed', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 3, 27, 16, 21), datetime.datetime(2011, 4, 1, 6, 23), u'Layout', u'(firefox5 fixed']", " datetime.datetime(2011, 3, 18, 17, 21), datetime.datetime(2011, 5, 10, 16, 49), u'Networking: Cookies', u'(firefox5 fixed']", " datetime.datetime(2011, 3, 17, 23, 35), datetime.datetime(2011, 6, 9, 9, 30), u'Graphics', u'(firefox5+ fixed']", " datetime.datetime(2011, 1, 16, 13, 54), datetime.datetime(2011, 5, 18, 11, 23), u'DOM', u'(firefox5 fixed']", " datetime.datetime(2011, 1, 29, 1, 6), datetime.datetime(2011, 3, 3, 16, 37), u'JavaScript Engine', u'(firefox5 fixed']", " datetime.datetime(2011, 3, 7, 15, 35), datetime.datetime(2011, 5, 11, 17, 15), u'DOM: Core & HTML', u'(firefox5+ fixed']", " datetime.datetime(2011, 3, 16, 17, 53), datetime.datetime(2011, 4, 27, 18, 46), u'DOM', u'(firefox5+ fixed']]]"]
# ["datetime.datetime(2010, 12, 6, 20, 17), datetime.datetime(2011, 3, 6, 7, 46), u'XUL', u'(firefox5 fixed']]]"]
# ["datetime.datetime(2011, 6, 13, 10, 59), datetime.datetime(2011, 8, 25, 20, 7), u'File Handling', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ fixed', u' firefox8+ fixed', u' firefox9+ fixed']", " datetime.datetime(2011, 6, 6, 10, 34), datetime.datetime(2011, 6, 7, 7, 49), u'File Handling', u'(firefox5+ fixed', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 5, 16, 13, 56), datetime.datetime(2011, 9, 30, 14, 30), u'Downloads API', u'(firefox5- wontfix', u' firefox6- wontfix', u' firefox7+ wontfix', u' firefox8+ fixed', u' firefox9+ fixed']]]"]
# ["datetime.datetime(2011, 6, 13, 16, 6), datetime.datetime(2011, 6, 15, 12, 58), u'JavaScript Engine', u'(firefox5+ fixed', u' firefox6+ fixed', u' firefox7+ fixed']]]"]
# ["datetime.datetime(2011, 3, 28, 8, 9), datetime.datetime(2011, 3, 30, 11, 30), u'Add-ons Manager', u'(firefox5 fixed']]]"]
# ["datetime.datetime(2011, 4, 14, 8, 33), datetime.datetime(2011, 5, 21, 16, 40), u'Serializers', u'(firefox5+ fixed']]]"]
# ["datetime.datetime(2011, 5, 15, 1, 42), datetime.datetime(2011, 5, 16, 8, 2), u'Canvas: WebGL', u'(firefox5+ fixed']]]"]
# ["datetime.datetime(2011, 5, 12, 14, 5), datetime.datetime(2011, 5, 16, 10, 51), u'Canvas: WebGL', u'(firefox5+ fixed']]]"]
# ["datetime.datetime(2011, 5, 10, 4, 56), datetime.datetime(2011, 8, 26, 5, 12), u'Canvas: WebGL', u'(firefox5+ fixed', u' firefox6+ fixed', u' firefox7+ fixed']", " datetime.datetime(2011, 5, 24, 9, 36), datetime.datetime(2011, 6, 16, 13, 17), u'Canvas: WebGL', u'(firefox5 fixed', u' firefox6 fixed', u' firefox7 fixed']", " datetime.datetime(2011, 5, 11, 6, 50), datetime.datetime(2011, 5, 20, 10, 59), u'Canvas: WebGL', u'(firefox5+ fixed', u' firefox6+ fixed']]]"]
# ["datetime.datetime(2011, 5, 9, 9, 25), datetime.datetime(2011, 6, 2, 15, 38), u'JavaScript Engine', u'(firefox5- unaffected', u' firefox6-']]]"]
# ["datetime.datetime(2011, 4, 21, 15, 11), datetime.datetime(2011, 4, 26, 15, 52), u'JavaScript Engine', u'(firefox5- unaffected', u' firefox6-']]]"]
# ["datetime.datetime(2011, 4, 6, 16, 34), datetime.datetime(2011, 10, 24, 20, 28), u'SVG', u'(firefox5 unaffected', u' firefox6 unaffected', u' firefox7 unaffected']]]"]
# ["datetime.datetime(2010, 12, 2, 13, 28), datetime.datetime(2011, 4, 1, 9, 35), u'Networking: Cookies', ]]]"]
# ["datetime.datetime(2011, 3, 9, 14, 28), datetime.datetime(2011, 4, 30, 19, 11), u'XSLT', ]]]"]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-2c22760cc32c> in <module>()
#       1 for file in files:
# ----> 2    durationB(file)
#
# <ipython-input-132-d0d2cbd9c087> in durationB(filename)
#       8             for row in csvReader:
#       9                 #try:
# ---> 10                 bugs = row[3].replace('[','').split('],')
#      11                 #lists = [map(int, s.replace(']','').split(',')) for s in bugs]
#      12                 print bugs
#
# IndexError: list index out of range

# %%
d3
# Out:
# {}

# %%
string='[[0,0,0], [0,0,1], [1,1,0]]'
t = eval(string)

# %%
type(t)
# Out:
# list

# %%
type(t[0])
# Out:
# list

# %%
firstBug = bugs[0]
                    #print firstBug
                    year = firstBug[0].year
                    minStart = firstBug[0]
                    maxEnd = firstBug[1] 
                    for i in range(1,len(bugs)):
                        if bugs[i][0] < minStart:
                            minStart = bugs[i][0]
                            year = bugs[i][0].year
                        if bugs[i][1] > maxEnd:
                            maxEnd = bugs[i][1]
                    duration = maxEnd - minStart
                    duration = (duration.total_seconds())/(24*3600*30)
                    if year in d3:
                        d3[year].append(duration)
                    else:
                        d3[year] = []

# %%
 a = "[[hjk,2,3],[4,5,6],[7,8,9]]"
import ast
m=ast.literal_eval(a)
print m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-0b45034555ae> in <module>()
#       1 a = "[[hjk,2,3],[4,5,6],[7,8,9]]"
#       2 import ast
# ----> 3 m=ast.literal_eval(a)
#       4 print m
#
# /Users/devyani/anaconda2/lib/python2.7/ast.pyc in literal_eval(node_or_string)
#      78                 return left - right
#      79         raise ValueError('malformed string')
# ---> 80     return _convert(node_or_string)
#      81
#      82
#
# /Users/devyani/anaconda2/lib/python2.7/ast.pyc in _convert(node)
#      58             return tuple(map(_convert, node.elts))
#      59         elif isinstance(node, List):
# ---> 60             return list(map(_convert, node.elts))
#      61         elif isinstance(node, Dict):
#      62             return dict((_convert(k), _convert(v)) for k, v
#
# /Users/devyani/anaconda2/lib/python2.7/ast.pyc in _convert(node)
#      58             return tuple(map(_convert, node.elts))
#      59         elif isinstance(node, List):
# ---> 60             return list(map(_convert, node.elts))
#      61         elif isinstance(node, Dict):
#      62             return dict((_convert(k), _convert(v)) for k, v
#
# /Users/devyani/anaconda2/lib/python2.7/ast.pyc in _convert(node)
#      77             else:
#      78                 return left - right
# ---> 79         raise ValueError('malformed string')
#      80     return _convert(node_or_string)
#      81
#
# ValueError: malformed string
